# %%
import pandas as pd
import csv
from numpy import genfromtxt
import matplotlib.pyplot as plt

headers = ['epoch', 'loss', 'acc', 'val_loss', 'val_acc']
df = genfromtxt('output/first_model.csv',delimiter=',',names=headers)
print (df)

x = df['epoch']
y1 = df['loss']
y2 = df['acc']
y3 = df['val_loss']
y4 = df['val_acc']

# plot
plt.xlabel ('Epochs')
plt.ylabel ('')
plt.title('Initial Training Loss and Accuracy')
plt.plot(x,y1,y2)


plt.show()
# Out:
# [( nan,        nan,    nan,    nan,    nan)
#  (  1., 1.1208e+00, 0.6375, 0.662 , 0.6452)
#  (  2., 6.6480e-01, 0.612 , 0.6279, 0.6452)
#  (  3., 6.4460e-01, 0.6589, 0.6265, 0.6452)
#  (  4., 6.2560e-01, 0.655 , 0.655 , 0.6452)
#  (  5., 5.7020e-01, 0.6993, 0.6136, 0.6452)
#  (  6., 6.0960e-01, 0.6951, 0.6162, 0.6613)
#  (  7., 5.3590e-01, 0.7089, 0.6414, 0.6613)
#  (  8., 6.0250e-01, 0.6979, 0.6011, 0.6774)
#  (  9., 5.1670e-01, 0.7702, 0.7225, 0.6613)
#  ( 10., 5.4140e-01, 0.7465, 0.6514, 0.6774)
#  ( 11., 4.8320e-01, 0.789 , 0.6582, 0.629 )
#  ( 12., 4.7290e-01, 0.7855, 0.6746, 0.6774)
#  ( 13., 4.2010e-01, 0.8008, 0.8519, 0.5968)
#  ( 14., 4.1450e-01, 0.8076, 0.6989, 0.6613)
#  ( 15., 3.6880e-01, 0.8306, 0.7425, 0.6452)
#  ( 16., 3.4580e-01, 0.8485, 0.7077, 0.6613)
#  ( 17., 2.9870e-01, 0.8896, 0.8519, 0.5806)
#  ( 18., 2.6390e-01, 0.8938, 1.0322, 0.6774)
#  ( 19., 2.7770e-01, 0.8889, 0.9424, 0.6452)
#  ( 20., 2.1850e-01, 0.9264, 1.0381, 0.6935)
# ...

# %%
# plot
plt.xlabel ('Epochs')
plt.ylabel ('')
plt.title('Initial Validation Loss and Accuracy')
plt.plot(x,y3,y4)
